# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy
import sklearn

# %%
# read New York State crime data (2013)
ny_crime = pd.read_excel("table_8_offenses_known_to_law_enforcement_new_york_by_city_2013.xls",skiprows=4)
ny_crime.head(5)
# Out:
#                        City  Population  Violent\ncrime  \
# 0             Adams Village      1861.0             0.0
# 1  Addison Town and Village      2577.0             3.0
# 2             Akron Village      2846.0             3.0
# 3                    Albany     97956.0           791.0
# 4            Albion Village      6388.0            23.0
#
#    Murder and\nnonnegligent\nmanslaughter  Rape\n(revised\ndefinition)1  \
# 0                                     0.0                           NaN
# 1                                     0.0                           NaN
# 2                                     0.0                           NaN
# 3                                     8.0                           NaN
# 4                                     0.0                           NaN
#
#    Rape\n(legacy\ndefinition)2  Robbery  Aggravated\nassault  Property\ncrime  \
# 0                          0.0      0.0                  0.0             12.0
# ...

# %%
ny_crime["PopulationSq"] = ny_crime["Population"].apply(lambda x: x**2)
ny_crime = ny_crime.rename(columns={"Murder and\nnonnegligent\nmanslaughter":"Murder"})
ny_crime.head(5)
# Out:
#                        City  Population  Violent\ncrime  Murder  \
# 0             Adams Village      1861.0             0.0     0.0
# 1  Addison Town and Village      2577.0             3.0     0.0
# 2             Akron Village      2846.0             3.0     0.0
# 3                    Albany     97956.0           791.0     8.0
# 4            Albion Village      6388.0            23.0     0.0
#
#    Rape\n(revised\ndefinition)1  Rape\n(legacy\ndefinition)2  Robbery  \
# 0                           NaN                          0.0      0.0
# 1                           NaN                          0.0      0.0
# 2                           NaN                          0.0      0.0
# 3                           NaN                         30.0    227.0
# 4                           NaN                          3.0      4.0
#
#    Aggravated\nassault  Property\ncrime  Burglary  Larceny-\ntheft  \
# 0                  0.0             12.0       2.0             10.0
# ...

# %% [markdown]
# ## Function Specification for Model:
#
# ### PropertyCrime = x + Population + Population^2 + Murder + Robbery

# %%
ny_crime_model = ny_crime[["Population","PopulationSq","Murder","Robbery"]]
ny_crime_model.head(5)
# Out:
#    Population  PopulationSq  Murder  Robbery
# 0      1861.0  3.463321e+06     0.0      0.0
# 1      2577.0  6.640929e+06     0.0      0.0
# 2      2846.0  8.099716e+06     0.0      0.0
# 3     97956.0  9.595378e+09     8.0    227.0
# 4      6388.0  4.080654e+07     0.0      4.0

# %%
# check for NaN values
ny_crime_model.isnull().sum()
# Out:
# Population      3
# PopulationSq    3
# Murder          3
# Robbery         3
# dtype: int64

# %%
for col in ny_crime_model.columns:
    print(ny_crime_model[ny_crime_model[col].isnull()][ny_crime_model.columns[ny_crime_model.isnull().any()]])
# Out:
#      Population  PopulationSq  Murder  Robbery
# 348         NaN           NaN     NaN      NaN
# 349         NaN           NaN     NaN      NaN
# 350         NaN           NaN     NaN      NaN
#      Population  PopulationSq  Murder  Robbery
# 348         NaN           NaN     NaN      NaN
# 349         NaN           NaN     NaN      NaN
# 350         NaN           NaN     NaN      NaN
#      Population  PopulationSq  Murder  Robbery
# 348         NaN           NaN     NaN      NaN
# 349         NaN           NaN     NaN      NaN
# 350         NaN           NaN     NaN      NaN
#      Population  PopulationSq  Murder  Robbery
# 348         NaN           NaN     NaN      NaN
# 349         NaN           NaN     NaN      NaN
# 350         NaN           NaN     NaN      NaN

# %%
# NaN count is low, can drop NaN values w/o large impact to dataset (NaN values appear to be in same rows)
ny_crime_model = ny_crime_model.dropna(how="all")
ny_crime_model.isnull().sum()
# Out:
# Population      0
# PopulationSq    0
# Murder          0
# Robbery         0
# dtype: int64

# %%
col_list = ny_crime_model.columns.values.tolist()

# %%
def convert_features(df_value):
    if df_value > 0:
        return 1
    else:
        return 0
    
# create new test_model with modified features (1 & 0)
test_model = pd.DataFrame(columns=col_list)

for col in col_list:
    model[col] = ny_crime_model[col].apply(convert_features)
test_model.head(5)
# Out:
#    Population  PopulationSq  Murder  Robbery
# 0           1             1       0        0
# 1           1             1       0        0
# 2           1             1       0        0
# 3           1             1       1        1
# 4           1             1       0        1

# %% [markdown]
# #### *For this model, please use variables to create categorical features where values greater than 0 are coded 1, and values equal to 0 are coded 0.
